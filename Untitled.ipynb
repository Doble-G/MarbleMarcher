# %% [markdown]
# <a href="https://colab.research.google.com/github/Doble-G/MarbleMarcher/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargo los dataset que tengo almacenados en googledrive

# %%
import numpy as np
import pandas as pd
import io
from google.colab import drive 
drive.mount('/content/gdrive')
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/train.csv')
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#      Age  Gender  ...  Albumin_and_Globulin_Ratio  Prediction
# 0     40    Male  ...                        0.60       False
# 1     64    Male  ...                        0.90        True
# 2     40  Female  ...                        1.60       False
# 3     32    Male  ...                        2.50       False
# 4     48    Male  ...                        1.70       False
# 5     27    Male  ...                        0.76        True
# 6     70    Male  ...                        0.75       False
# 7     26    Male  ...                        0.60       False
# 8     60    Male  ...                        0.40       False
# 9     25    Male  ...                        0.70        True
# 10    42  Female  ...                        1.00       False
# 11    53    Male  ...                        1.50        True
# ...

# %%
print(df.shape)
# Out:
# (437, 11)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Prediction'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 11 columns):
# Age                           437 non-null int64
# Gender                        437 non-null object
# Total_Bilirubin               437 non-null float64
# Direct_Bilirubin              437 non-null float64
# Alkaline_Phosphotase          437 non-null int64
# Alamine_Aminotransferase      437 non-null int64
# Aspartate_Aminotransferase    437 non-null int64
# Total_Protiens                437 non-null float64
# Albumin                       437 non-null float64
# Albumin_and_Globulin_Ratio    437 non-null float64
# Prediction                    437 non-null bool
# dtypes: bool(1), float64(5), int64(4), object(1)
# memory usage: 34.6+ KB
# None

# %% [markdown]
# ¿Cual es  el numero de positivos en  nuesta muestra?

# %%
df['Prediction'].mean()
# Out:
# 0.2906178489702517

# %% [markdown]
# ¿Cual es la porporcion de hombres con predicion verdadera frente a los que no?

# %%
df[df['Gender'] == 'Male']['Prediction'].mean()
# Out:
# 0.2599388379204893

# %% [markdown]
# ¿Cual es la porporcion de mujeres con predicion verdadera frente a los que no?

# %%
df[df['Gender'] == 'Female']['Prediction'].mean()
# Out:
# 0.38181818181818183

# %% [markdown]
# ¿Edad media de los posivos?

# %%
df[df['Prediction'] == True]['Age'].mean()
# Out:
# 41.45669291338583
